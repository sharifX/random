# %% [markdown]
# # Scientific Names tool  comparison
#
# A simple notebook showing how different tools provide different responses for species scientific names.
#
# This is a test dataset (plants) that contain real names, wrong author names, typos.
# ```
# scientificName
# Pinus mugo Turra
# Pinus mugo Smith
# Vicia faba L.
# Vicia faba S.
# Vicia faba
# Vicia fava
# ```

# %%
#GBIF API response 
from pygbif import species
import json

# This is a match and ACCEPTED name 
species.name_suggest(q='Pinus mugo Turra')
# Out:
# [{'key': 5285385,
#   'kingdom': 'Plantae',
#   'phylum': 'Tracheophyta',
#   'order': 'Pinales',
#   'family': 'Pinaceae',
#   'genus': 'Pinus',
#   'species': 'Pinus mugo',
#   'kingdomKey': 6,
#   'phylumKey': 7707728,
#   'classKey': 194,
#   'orderKey': 640,
#   'familyKey': 3925,
#   'genusKey': 2684241,
#   'speciesKey': 5285385,
#   'parent': 'Pinus',
#   'parentKey': 2684241,
#   'nubKey': 5285385,
#   'scientificName': 'Pinus mugo Turra',
#   'canonicalName': 'Pinus mugo',
#   'rank': 'SPECIES',
#   'status': 'ACCEPTED',
#   'higherClassificationMap': {'6': 'Plantae',
#    '7707728': 'Tracheophyta',
#    '194': 'Pinopsida',
#    '640': 'Pinales',
#    '3925': 'Pinaceae',
#    '2684241': 'Pinus'},
#   'synonym': False,
#   'class': 'Pinopsida'}]

# %%
# Try with different/wrong author name
# No match, no response 
species.name_suggest(q='Pinus mugo Smith')
# Out:
# []

# %%
# Try with no author name 
result = species.name_suggest(q='Pinus mugo')

# %%
for names in result:
    print(names['scientificName']+","+names['status'])
# Out:
# Pinus mugo Turra,ACCEPTED
# Pinus mugo subsp. rostrata (Antoine) Hoopes,SYNONYM
# Pinus mugo nothosubsp. rotundata (Link) A.E.Murray, 1985,SYNONYM
# Pinus mugo subsp. mughus (Scop.) O.Schwarz, 1949,SYNONYM
# Pinus mugo subsp. pumilio (Haenke) A.E.Murray, 1983,SYNONYM
# Pinus mugo var. arborea (Tubeuf) Hyl.,SYNONYM
# Pinus mugo var. rotundata (Link) Hoopes,SYNONYM
# Pinus mugo var. pumilio (Haenke) Domin,SYNONYM
# Pinus mugo var. uncinata (Ramond ex DC.) Fiori,SYNONYM
# Pinus mugo var. rotundata (Link) Zenari,SYNONYM
# Pinus mugo var. mughus (Scop.) Zenari,SYNONYM
# Pinus mugo var. nana Loudon ex Godr.,SYNONYM
# Pinus mugo var. rostrata (Antoine) Domin,SYNONYM
# Pinus mugo var. palustris (Hagenb.) Breistr.,SYNONYM
# Pinus mugo subsp. mugo,ACCEPTED
# Pinus mugo subsp. uliginosa G.E.Neumann ex Silba,SYNONYM
# Pinus mugo subsp. pumilio (Haenke) Franco,SYNONYM
# Pinus mugo subsp. mughus (Scop.) Domin,SYNONYM
# Pinus mugo subsp. pseudopumilio (Willk.) Holubickova,SYNONYM
# Pinus mugo subsp. uncinata (Ramond ex DC.) Domin,SYNONYM
# Pinus mugo f. mughoides (Willk.) K.I.Chr.,SYNONYM
# Pinus mugo subsp. uliginosa G.E.Neumann,HOMOTYPIC_SYNONYM
# Pinus mugo var. compacta D.Hill,SYNONYM
# Pinus mugo var. pseudopumilio (Willk.) Domin,SYNONYM
# Pinus mugo var. pumilio (Haenke) Zenari,SYNONYM
# Pinus mugo f. mugo,SYNONYM
# Pinus mugo f. slavinii (Hornibr.) Rehder,SYNONYM
# Pinus mugo subsp. pumilio (Haenke) Zenari,SYNONYM
# Pinus mugo subsp. rotundata (Link) Janch. & H.Neumayer,ACCEPTED
# Pinus mugo var. nana Loudon ex Gordon,SYNONYM
# Pinus mugo var. nana Loudon,HOMOTYPIC_SYNONYM
# Pinus mugo subsp. arborea (Tubeuf) Hyl.,SYNONYM
# Pinus mugo subsp. uliginosa (Neuman ex Wimm.) O.Schwarz,SYNONYM
# Pinus mugo subsp. rostrata (Antoine) E.Murray,SYNONYM
# Pinus mugo var. rostrata (Antoine) Hoopes,SYNONYM
# Pinus mugo f. compacta (D.Hill) Rehder,SYNONYM
# Pinus mugo f. applanata (Willk.) K.I.Chr.,SYNONYM
# Pinus mugo × sylvestris,ACCEPTED
# Pinus mugo x sylvestris,ACCEPTED
# Pinus mugo subsp. × rotundata,ACCEPTED
# Pinus mugo ssp. × rotundata,SYNONYM
# Pinus mugo subsp. x rotundata,SYNONYM
# Pinus mugo ssp. x rotundata,SYNONYM

# %%
# correct suffix, matches, ACCEPTED
species.name_suggest(q='Vicia faba L.')
# Out:
# [{'key': 2974832,
#   'kingdom': 'Plantae',
#   'phylum': 'Tracheophyta',
#   'order': 'Fabales',
#   'family': 'Fabaceae',
#   'genus': 'Vicia',
#   'species': 'Vicia faba',
#   'kingdomKey': 6,
#   'phylumKey': 7707728,
#   'classKey': 220,
#   'orderKey': 1370,
#   'familyKey': 5386,
#   'genusKey': 2974751,
#   'speciesKey': 2974832,
#   'parent': 'Vicia',
#   'parentKey': 2974751,
#   'nubKey': 2974832,
#   'scientificName': 'Vicia faba L.',
#   'canonicalName': 'Vicia faba',
#   'rank': 'SPECIES',
#   'status': 'ACCEPTED',
#   'higherClassificationMap': {'6': 'Plantae',
#    '7707728': 'Tracheophyta',
#    '220': 'Magnoliopsida',
#    '1370': 'Fabales',
#    '5386': 'Fabaceae',
#    '2974751': 'Vicia'},
#   'synonym': False,
#   'class': 'Magnoliopsida'}]

# %%
# try with a wrong suffix, no response
species.name_suggest(q='Vicia faba S.')
# Out:
# []

# %%
# try with out any suffix 
faba = species.name_suggest(q='Vicia faba')
for names in faba:
    print(names['scientificName']+","+names['status'])
# Out:
# Vicia faba L.,ACCEPTED
# Vicia faba subsp. minor (Peterm.) Rothm., 1963,SYNONYM
# Vicia faba subsp. equina Rothm., 1963,SYNONYM
# Vicia faba f. minor (Harz) Beck,SYNONYM
# Vicia faba subsp. paucijuga (Alef.) Muratova,ACCEPTED
# Vicia faba var. equina St.-Amans,DOUBTFUL
# Vicia faba subsp. faba,SYNONYM
# Vicia faba var. minor Beck,ACCEPTED
# Vicia faba var. equina Pers.,ACCEPTED
# Vicia faba f. major (Harz) Beck,SYNONYM
# Vicia faba var. minor Peterm.,SYNONYM
# Vicia faba subsp. equina (Pers.) Schübl. & G.Martens, 1834,SYNONYM
# Vicia faba var. faba,ACCEPTED
# Vicia faba var. minuta (hort. ex Alef.) Mansf.,SYNONYM
# Uromyces viciae-fabae subsp. viciae-fabae,SYNONYM
# Uromyces viciae-fabae (Pers.) J.Schröt.,ACCEPTED
# Hendersonia viciae-fabae Savelli,ACCEPTED
# Alternaria viciae-fabae E.G.Simmons & G.F.Laundon,ACCEPTED
# Uredo viciae-fabae Pers.,SYNONYM
# Uromyces viciae-fabae var. orobi (Schumach.) Jørst.,SYNONYM
# Vicia faba alphaendornavirus,ACCEPTED

# %%
#mistake
species.name_suggest(q='Vicia fava')
# Out:
# []

# %% [markdown]
# # Catalogue of Life tool
# https://data.catalogueoflife.org/tools/name-match
# import the following file and get the result.
# ```
# scientificName
# Pinus mugo Turra
# Pinus mugo Smith
# Vicia faba L.
# Vicia faba S.
# Vicia faba
# Vicia fava
# ```

# %%
from IPython.display import Image
Image(filename='/Users/sharifislam/col_result.png')

# %% [markdown]
# Here we tried the same names from GBIF test above but we get different response. Instead of ACCEPTED we see exact, canonical, variant, none.

# %%
 #above data in csv format
    #matchType
import csv
with open('/Users/sharifislam/Namematch_result_COL21.10.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
      print(row[0]+","+row[1]+","+row[3]+","+row[5])
# Out:
# ﻿"providedScientificName",matchType,taxonId,scientificName
# Pinus mugo Turra,exact,4J2CJ,Pinus mugo Turra
# Pinus mugo Smith,canonical,4J2CJ,Pinus mugo Turra
# Vicia faba L.,variant,7G2QH,Vicia faba L.
# Vicia faba S.,canonical,7G2QH,Vicia faba L.
# Vicia faba,exact,7G2QH,Vicia faba L.
# Vicia fava,none,,

# %% [markdown]
# A few other web friendly tools
# http://match.taibif.tw/about.html
# "NomenMatch is a tool for taxonomists to match a set of species names against other sets with certain authority. It returns matched names, ids, usage status, and links to original sources. So not only the matched results, users can also know about differences of name usage among different sources. This is important because we believe that there is no absolute right or wrong, and only different perspectives in taxonomy. This tool provides easily references for taxonomists."
#
# Test query link:
# http://match.taibif.tw/api.php?names=Pinus%20mugo%20Turra|Pinus%20mugo%20Smith|Vicia%20faba%20L.|Vicia%20faba%20S.|Vicia%20faba|Vicia%20fava

# %% [markdown]
# Taxonomic name resolution service:
# 2013 paper https://dx.doi.org/10.1186%2F1471-2105-14-16
# https://tnrs.biendata.org/#
# This has a score but uses different backbone

# %%
Image(filename='/Users/sharifislam/tnrs-results.png')
